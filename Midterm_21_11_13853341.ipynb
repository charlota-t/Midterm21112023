# %%
import requests
import pandas as pd
import time
import sys

import numpy as np

# %%
df_AAPL = pd.read_csv(r'C:\Users\charl\Downloads\13853341\data\AAPL.csv', sep = ',', on_bad_lines= 'skip')
df_ABBV = pd.read_csv(r'C:\Users\charl\Downloads\13853341\data\ABBV.csv', sep = ',', on_bad_lines= 'skip')
df_EA = pd.read_csv(r'C:\Users\charl\Downloads\13853341\data\EA.csv', sep = ',', on_bad_lines= 'skip')
df_GM = pd.read_csv(r'C:\Users\charl\Downloads\13853341\data\GM.csv', sep = ',', on_bad_lines= 'skip')
df_OKE = pd.read_csv(r'C:\Users\charl\Downloads\13853341\data\OKE.csv', sep = ',', on_bad_lines= 'skip')

# %%
df_AAPL.head()
# Out:
#          Date       High        Low       Open      Close       Volume  \
# 0  2017-11-13  43.625000  43.349998  43.375000  43.492500   67928400.0
# 1  2017-11-14  43.369999  42.794998  43.259998  42.834999   99130000.0
# 2  2017-11-15  42.580002  42.095001  42.492500  42.270000  116632400.0
# 3  2017-11-16  42.967499  42.575001  42.794998  42.775002   94550000.0
# 4  2017-11-17  42.847500  42.410000  42.759998  42.537498   87598000.0
#
#    Adj Close
# 0  41.357002
# 1  40.731789
# 2  40.194534
# 3  40.674740
# 4  40.448902

# %%
df_AAPL = df_AAPL.rename(columns = {'Adj Close' : 'Adj_Close'})

# %%
df_ABBV = df_ABBV.rename(columns = {'Adj Close' : 'Adj_Close'})

# %%
df_EA = df_EA.rename(columns = {'Adj Close' : 'Adj_Close'})

# %%
df_GM = df_GM.rename(columns = {'Adj Close' : 'Adj_Close'})

# %%
df_OKE = df_OKE.rename(columns = {'Adj Close' : 'Adj_Close'})

# %%
df = ['df_AAPL', 'df_ABBV', 'df_EA', 'df_GM', 'df_OKE']

# %%
#for i in df:
    #i[i.Close == i.Adj_Close]
    #i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 2
#       1 for i in df:
# ----> 2     i[i.Close == i.Adj_Close]
#       3     i
#
# AttributeError: 'str' object has no attribute 'Close'

# %%
df_OKE[df_OKE.Close == df_OKE.Adj_Close]
# Out:
#             Date       High        Low       Open      Close     Volume  \
# 1059  2022-01-28  59.349998  57.560001  59.099998  59.290001  2445700.0
# 1060  2022-01-31  60.700001  58.610001  59.240002  60.680000  2795400.0
# 1061  2022-02-01  62.000000  59.700001  60.130001  61.869999  2535600.0
# 1062  2022-02-02  63.040001  61.529999  62.060001  62.889999  3809400.0
# 1063  2022-02-03  62.580002  61.430000  62.209999  62.070000  2088100.0
# ...          ...        ...        ...        ...        ...        ...
# 1254  2022-11-07  61.880001  60.439999  61.180000  61.860001  2129500.0
# 1255  2022-11-08  62.900002  61.400002  61.939999  62.660000  2090300.0
# 1256  2022-11-09  62.349998  60.750000  62.270000  60.860001  3000600.0
# 1257  2022-11-10  63.450001  62.020000  62.500000  63.400002  2627200.0
# 579   2020-03-05  30.770000  30.010000  30.540001  30.100000  17921300.0
# 580   2020-03-06  29.540001  28.450001  29.209999  28.690001  20009500.0
# 581   2020-03-09  26.120001  24.150000  26.000000  24.690001  28350600.0
# 582   2020-03-10  27.139999  24.590000  25.980000  27.120001  18287700.0
# 583   2020-03-11  26.620001  25.760000  26.000000  26.000000  21309700.0
# ...          ...        ...        ...        ...        ...         ...
# 1254  2022-11-07  39.470001  38.689999  39.360001  39.389999  11526900.0
# 1255  2022-11-08  39.509998  38.509998  39.470001  39.049999  10946400.0
# 1256  2022-11-09  38.869999  38.029999  38.549999  38.060001  10526200.0
# 1257  2022-11-10  40.599998  38.860001  39.150002  39.740002  20197600.0
# 1258  2022-11-11  41.580002  39.820000  39.860001  41.119999  13033000.0
#
#       Adj_Close
# 579   30.100000
# 580   28.690001
# 581   24.690001
# 582   27.120001
# ...

# %% [raw]
# 1. as we can see all companies have a date where there is no difference between the Close time and Adjusted Close Time

# %%
max_AAPL = max(df_AAPL.Adj_Close)
min_AAPL = min(df_AAPL.Adj_Close)
max_ABBV = max(df_ABBV.Adj_Close)
min_ABBV = min(df_ABBV.Adj_Close)
max_EA = max(df_EA.Adj_Close)
min_EA = min(df_EA.Adj_Close)
max_GM = max(df_GM.Adj_Close)
min_GM = min(df_GM.Adj_Close)
max_OKE = max(df_OKE.Adj_Close)
min_OKE = min(df_OKE.Adj_Close)

# %%
max_AAPL
# Out:
# 180.9597320556641

# %%
min_AAPL
# Out:
# 34.30958938598633

# %%
max_ABBV
# Out:
# 170.14651489257812

# %%
min_ABBV
# Out:
# 54.02183151245117

# %%
max_EA
# Out:
# 148.60855102539062

# %%
min_EA
# Out:
# 74.43951416015625

# %%
max_GM
# Out:
# 65.73999786376953

# %%
min_GM
# Out:
# 16.799999237060547

# %%
max_OKE
# Out:
# 73.62000274658203

# %%
min_OKE
# Out:
# 12.773762702941896

# %% [raw]
# 2. above are all the min and max prices per company

# %%
df = pd.read_csv('https://ies-python-midterm.s3.eu-central-1.amazonaws.com/companies/companies_no_subindustry.csv', sep = ',', on_bad_lines = 'skip')

# %%
df.head(10)
# Out:
#   Symbol             Security             GICS_Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT               Abbott             Health Care
# 3   ABBV               AbbVie             Health Care
# 4   ABMD              Abiomed             Health Care
# 5    ACN            Accenture  Information Technology
# 6   ATVI  Activision Blizzard  Communication Services
# 7    ADM                  ADM        Consumer Staples
# 8   ADBE           Adobe Inc.  Information Technology
# 9    ADP                  ADP  Information Technology
#
#                          hq    included      Founded
# 0     Saint Paul, Minnesota  09.08.1976         1902
# 1      Milwaukee, Wisconsin  26.07.2017         1916
# 2   North Chicago, Illinois  31.03.1964         1888
# 3   North Chicago, Illinois  31.12.2012  2013 (1888)
# 4    Danvers, Massachusetts  31.05.2018         1981
# ...

# %%
empty = 0
full = 0
for df.included in df:
    try:
        full += 1  
    except:
        empty += 1
empty
# Out:
# 0
